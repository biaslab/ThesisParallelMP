# %%
import Pkg; Pkg.activate(".."); Pkg.instantiate();
# Out:
#   Activating project at `c:\Users\matti\Documents\TUe\Thesis\ThesisParallelMP`

# %%
using RxInfer, Distributions, LinearAlgebra, Random, Plots, Parameters, ProgressMeter, StableRNGs, PGFPlotsX

# %%
@show Threads.nthreads(), Threads.nthreads(:interactive)
# Out:
# (Threads.nthreads(), Threads.nthreads(:interactive)) = (8, 0)
# (8, 0)

# %%
includet("../multithreading.jl")

# %%
function generate_data(rng, n)
    return sin.(range(1, 4.0; length = n)) .+ 0.1 * rand(rng, n)
end
# Out:
# generate_data (generic function with 1 method)

# %%
struct NormalMeta
	size::Int
end

function factorial(n)
    if n == 0 || n == 1
        return 1
    else
        return factorial(n - 1) + factorial(n - 2)
    end
end

@rule NormalMeanVariance(:out, Marginalisation) (q_μ::Any, q_v::Any, meta::NormalMeta) = begin
    s = factorial(meta.size) / 10^8
    return @call_rule NormalMeanVariance(:out, Marginalisation) (q_μ = q_μ, q_v = PointMass(mean(q_v) + s))
end

@rule NormalMeanVariance(:μ, Marginalisation) (q_out::Any, q_v::Any, meta::NormalMeta) = begin
    s = factorial(meta.size) / 10^8
    return @call_rule NormalMeanVariance(:μ, Marginalisation) (q_out = q_out, q_v = PointMass(mean(q_v) + s))
end

@rule NormalMeanVariance(:out, Marginalisation) (m_μ::Any, q_v::Any, meta::NormalMeta) = begin
    s = factorial(meta.size) / 10^8
    return @call_rule NormalMeanVariance(:out, Marginalisation) (m_μ = m_μ, q_v = PointMass(mean(q_v) + s))
end

@rule NormalMeanVariance(:μ, Marginalisation) (m_out::Any, q_v::Any, meta::NormalMeta) = begin
    s = factorial(meta.size) / 10^8
    return @call_rule NormalMeanVariance(:μ, Marginalisation) (m_out = m_out, q_v = PointMass(mean(q_v) + s))
end

@average_energy NormalMeanVariance (q_out_μ::MultivariateNormalDistributionsFamily, q_v::Any, meta::NormalMeta) = begin
    out_μ_mean, out_μ_cov = mean_cov(q_out_μ)
    return (ReactiveMP.log2π + mean(log, q_v) + mean(inv, q_v) * (out_μ_cov[1, 1] + out_μ_cov[2, 2] - out_μ_cov[1, 2] - out_μ_cov[2, 1] + abs2(out_μ_mean[1] - out_μ_mean[2]))) / 2
end

# %%
struct GammaMeta
	size::Int
end

@rule NormalMeanPrecision(:μ, Marginalisation) (q_out::PointMass, q_τ::Any, meta::GammaMeta) = begin
    s = factorial(meta.size) / 10^8
    return @call_rule NormalMeanPrecision(:μ, Marginalisation) (q_out = PointMass(mean(q_out) + s), q_τ = q_τ)
end

@rule NormalMeanPrecision(:τ, Marginalisation) (q_out::PointMass, q_μ::Any, meta::GammaMeta) = begin
    s = factorial(meta.size) / 10^8
    return @call_rule NormalMeanPrecision(:τ, Marginalisation) (q_out = PointMass(mean(q_out) + s), q_μ = q_μ)
end

@average_energy NormalMeanPrecision (q_out::Any, q_μ::Any, q_τ::Any, meta::GammaMeta) = begin
    μ_mean, μ_var     = mean_var(q_μ)
    out_mean, out_var = mean_var(q_out)
    return (ReactiveMP.log2π - mean(log, q_τ) + mean(q_τ) * (μ_var + out_var + abs2(μ_mean - out_mean))) / 2
end

# %%
@model function state_space_model(n, size, prod_strategy, pipeline_states, pipeline_shared)
    # We create a sequence of random variables for hidden states
    x = randomvar(n)
    τ_y = randomvar() where { prod_strategy = prod_strategy }
    # As well a sequence of observartions
    y = datavar(Float64, n)

    states_meta = NormalMeta(size)
    precision_meta = GammaMeta(size)

    x0 ~ Normal(mean = 0.0, precision = 1.0)
    τ_y ~ Gamma(shape = 1.0, rate = 1.0)

    x_i_min = x0

    for i in 1:n
        x[i] ~ Normal(mean = x_i_min, variance = 1.0) where { pipeline = pipeline_states, meta = states_meta }
        y[i] ~ Normal(mean = x[i], precision = τ_y) where { pipeline = pipeline_shared, meta = precision_meta }
        x_i_min = x[i]
    end
end

# %%
seed = 123
rng  = StableRNG(seed)
n = 100

data = generate_data(rng, n);

constraints = @constraints begin
    q(x0, τ_y, x) = q(x0, x)q(τ_y)
end

results = infer(
    model = state_space_model(n, 10, nothing, ThreadsReusingPipelineStage(vague(NormalMeanVariance)), ThreadsPipelineStage()),
    data  = (y = data,),
    iterations    = 20,
    returnvars    = KeepLast(),
    options       = (limit_stack_depth = 100, ),
    initmarginals = (τ_y = Gamma(100.0, 100.0), ),
    constraints  = constraints,
    free_energy = true
);
plot(mean.(results.posteriors[:x]), ribbon = std.(results.posteriors[:x]))
scatter!(data)

# %%
pgfplotsx()
# Out:
# Plots.PGFPlotsXBackend()

# %%
niterations = 100
limit_stack_depth = 100
size_slow = 5

results1 = infer(
    model = state_space_model(n, size_slow, nothing, nothing, nothing),
    data  = (y = data,),
    iterations    = niterations,
    returnvars    = KeepLast(),
    options       = (limit_stack_depth = limit_stack_depth, ),
    initmarginals = (τ_y = Gamma(0.1, 0.1), ),
    constraints  = constraints,
    free_energy = true
);

results2 = infer(
    model = state_space_model(n, size_slow, nothing, ThreadsReusingPipelineStage(vague(NormalMeanVariance)), nothing),
    data  = (y = data,),
    iterations    = niterations,
    returnvars    = KeepLast(),
    options       = (limit_stack_depth = limit_stack_depth, ),
    initmarginals = (τ_y = Gamma(0.1, 0.1), ),
    constraints  = constraints,
    free_energy = true
);

results3 = infer(
    model = state_space_model(n, size_slow, nothing, ThreadsSoftReusingPipelineStage(vague(NormalMeanVariance)), nothing),
    data  = (y = data,),
    iterations    = niterations,
    returnvars    = KeepLast(),
    options       = (limit_stack_depth = limit_stack_depth, ),
    initmarginals = (τ_y = Gamma(0.1, 0.1), ),
    constraints  = constraints,
    free_energy = true
);

p1 = plot((abs.(results1.free_energy .- results2.free_energy)), label = "reusing")
p1 = plot!(p1, (abs.(results3.free_energy .- results1.free_energy)), label = "soft reusing")

p2 = plot(abs.(diff(results2.free_energy)) .+ 10^-10, yaxis = :log, label = "reusing")
p2 = plot!(p2, abs.(diff(results1.free_energy))  .+ 10^-10, label = "sequential")
p2 = plot!(p2, abs.(diff(results3.free_energy))  .+ 10^-10, label = "soft reusing")

plot(p1, p2)

# %%
function execute_benchmark(f::F, n = 1000) where { F }

    # For the compilation
    f()

    GC.gc()
    GC.gc(true)

    times = Vector{Float64}(undef, n)

    for i in 1:n
        times[i] = f()
    end

    return times
end
# Out:
# execute_benchmark (generic function with 2 methods)

# %%
function benchmark_rule(size; n = 1000)
    times = Vector{Float64}(undef, n)

    m_out = NormalMeanVariance(0, 1)
    m_μ = NormalMeanVariance(0, 1)
    q_v = PointMass(1)
    meta = NormalMeta(size)

    x_rule = @call_rule NormalMeanVariance(:out, Marginalisation) (m_μ = m_μ, q_v = q_v, meta = meta)
    y_rule = @call_rule NormalMeanVariance(:μ, Marginalisation) (m_out = m_out, q_v = q_v, meta = meta)

    for i in 1:n
        start_time = time_ns()

        x_rule = @call_rule NormalMeanVariance(:out, Marginalisation) (m_μ = m_μ, q_v = q_v, meta = meta)
        y_rule = @call_rule NormalMeanVariance(:μ, Marginalisation) (m_out = m_out, q_v = q_v, meta = meta)

        times[i] = time_ns() - start_time
    end

    return times / 1000
end
# Out:
# benchmark_rule (generic function with 1 method)

# %%
function prepare_benchmark(prod, pipeline_states, pipeline_shared, size, n, niterations = 100, stop_tol = nothing)
    return () -> begin
        timing = Ref(0.0)
        current_iter = Ref(0.0)

        data = generate_data(rng, n)
        moptions = (limit_stack_depth = 100, )

        result = infer(
            model = state_space_model(n, size, prod, pipeline_states, pipeline_shared),
            data  = (y = data,),
            callbacks = (
                before_iteration = (model, iteration) -> begin
                    current_iter[] = time_ns()
                    return false
                end,
                after_iteration = (model, iteration) -> begin
                    current_iter[] = time_ns() - current_iter[]
                    timing[] = timing[] + current_iter[]
                    return false
                end
            ),
            iterations    = niterations,
            options       = moptions,
            initmarginals = (τ_y = Gamma(1.0, 1.0), ),
            constraints   = constraints,
            free_energy   = true
        )

        if !isnothing(stop_tol)
            num_iter = findfirst(<(stop_tol), abs.(diff(result.free_energy)))
            if isnothing(num_iter)
                return timing[]
            end
            return timing[] / niterations * num_iter
        end
        return timing[]
    end
end
# Out:
# prepare_benchmark (generic function with 3 methods)

# %%
function run_big_benchmark(combinations, orders, n; nsamples = 10, niterations = 100, stop_tol = nothing)
    return @showprogress map(orders) do order

        results = Dict()
        results[:rule] = benchmark_rule(order)

        for (key, combination) in combinations
            _b_combination = prepare_benchmark(combination[1], combination[2], combination[3], order, n, niterations, stop_tol)
            results[key] = execute_benchmark(_b_combination, nsamples)
        end

        return (order, results)
    end
end
# Out:
# run_big_benchmark (generic function with 1 method)

# %%
combinations = [
    :sequential => (nothing, nothing, nothing),
    :all_parallel => (CustomProdStrategy(fifo_prod), ThreadsSoftReusingPipelineStage(vague(NormalMeanVariance)), ThreadsPipelineStage()),
    :all_reusing_fifo => (CustomProdStrategy(fifo_prod), ThreadsSoftReusingPipelineStage(vague(NormalMeanVariance)), nothing),
    :parallel_reusing_only => (nothing, ThreadsReusingPipelineStage(vague(NormalMeanVariance)), nothing),
    :parallel_soft_reusing_only => (nothing, ThreadsSoftReusingPipelineStage(vague(NormalMeanVariance)), nothing),
]
# Out:
# 6-element Vector{Pair{Symbol, Tuple{Any, Any, Any}}}:
#                  :sequential => (nothing, nothing, nothing)
#                :all_parallel => (CustomProdStrategy{typeof(fifo_prod)}(fifo_prod), ThreadsSoftReusingPipelineStage{NormalMeanVariance{Float64}}(NormalMeanVariance{Float64}(μ=0.0, v=1.0e12)), ThreadsPipelineStage())
#            :all_reusing_fifo => (CustomProdStrategy{typeof(fifo_prod)}(fifo_prod), ThreadsSoftReusingPipelineStage{NormalMeanVariance{Float64}}(NormalMeanVariance{Float64}(μ=0.0, v=1.0e12)), nothing)
#       :parallel_reusing_only => (nothing, ThreadsReusingPipelineStage{NormalMeanVariance{Float64}}(NormalMeanVariance{Float64}(μ=0.0, v=1.0e12)), nothing)
#  :parallel_soft_reusing_only => (nothing, ThreadsSoftReusingPipelineStage{NormalMeanVariance{Float64}}(NormalMeanVariance{Float64}(μ=0.0, v=1.0e12)), nothing)
#        :parallel_all_reusing => (nothing, ThreadsReusingPipelineStage{NormalMeanVariance{Float64}}(NormalMeanVariance{Float64}(μ=0.0, v=1.0e12)), ThreadsReusingPipelineStage{Gamma{Float64}}(Gamma{Float64}(α=1.0, θ=1.0e12)))

# %%
function plot_benchmark(combinations, sizes, n, niterations, stop_tol = nothing)
    rule_results = run_big_benchmark(combinations, sizes, n; niterations = niterations, stop_tol = stop_tol);

    sizes = getindex.(rule_results, 1)
    benchmarks = getindex.(rule_results, 2)
    names = [first.(combinations); :rule]

    points = map(names) do name
        name => minimum.(getindex.(benchmarks, name))
    end |> Dict

    p = plot(
        xaxis = :log,
        yaxis = :log,
        legend = false,
        xlabel = "Rule time [μs]",
        ylabel = "Relative speed [-]",
        yticks = ([1:8;], [string(a) for a in 1:8]),
        ylim = (0.3, 8),
        gridalpha = 0.3,
        title = "N = $n",
    )

    for (key, values) in pairs(points)
        if key != :rule
            plot!(p, points[:rule], points[:sequential] ./ values, label = string(key))
        end
    end

    return p
end
# Out:
# plot_benchmark (generic function with 2 methods)

# %%
names = first.(combinations)

ordered_combinations = map(names) do name
    name => 0
end |> Dict;

# %%
sizes = 10:2:22
niterations = 10

p1 = plot_benchmark(combinations, sizes, 50, niterations)
p2 = plot_benchmark(combinations, sizes, 200, niterations);
# Out:
# `ProductOf` object cannot be used as a functional form in inference backend. Use form constraints to restrict the functional form of marginal posteriors.
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] constrain_form(::UnspecifiedFormConstraint, something::ProductOf{NormalMeanVariance{Float64}, Gamma{Float64}})
#     @ ReactiveMP C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\constraints\form.jl:140
#   [3] constrain_form_as_message(message::Message{ProductOf{NormalMeanVariance{Float64}, Gamma{Float64}}, Nothing}, form_constraint::UnspecifiedFormConstraint)
#     @ ReactiveMP C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\message.jl:140
#   [4] (::ReactiveMP.var"#15#17"{GenericProd, UnspecifiedFormConstraint})(messages::Vector{AbstractMessage})
#     @ ReactiveMP C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\message.jl:150
#   [5] next_received!(wrapper::Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#15#17"{GenericProd, UnspecifiedFormConstraint}}, data::ChanneledMessage{Channel{Any}}, index::CartesianIndex{1})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\collected.jl:97
#   [6] on_next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\collected.jl:87 [inlined]
#   [7] scheduled_next!(actor::Rocket.CollectLatestObservableInnerActor{AbstractMessage, CartesianIndex{1}, Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#15#17"{GenericProd, UnspecifiedFormConstraint}}}, value::ChanneledMessage{Channel{Any}}, ::AsapScheduler)
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\schedulers\asap.jl:23
#   [8] on_next!(subject::Subject{AbstractMessage, AsapScheduler, AsapScheduler}, data::ChanneledMessage{Channel{Any}})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\subjects\subject.jl:62
#   [9] actor_on_next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:250 [inlined]
#  [10] next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:202 [inlined]
#  [11] on_next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\subjects\recent.jl:62 [inlined]
#  [12] #7
#     @ C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\rocket.jl:86 [inlined]
#  [13] limitstack(callback::RxInfer.var"#7#8"{Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ChanneledMessage{Channel{Any}}}, instance::RxInfer.LimitStackScheduler)
#     @ RxInfer C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\rocket.jl:52
#  [14] scheduled_next!
#     @ C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\rocket.jl:86 [inlined]
#  [15] actor_on_next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:255 [inlined]
#  [16] next!(actor::Actor{T}, data::T) where T
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:203 [inlined]
#  [17] on_next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\scheduled.jl:12 [inlined]
#  [18] next!(actor::Actor{T}, data::T) where T
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:206 [inlined]
#  [19] on_next!(actor::Rocket.MapActor{Tuple{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, Tuple{SingleObservable{Marginal{PointMass{Float64}, Nothing}, AsapScheduler}}}, Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}}, ReactiveMP.MarginalMapping{NormalMeanVariance, Val{:out_μ}, Val{(:out, :μ)}, Val{(:v,)}, NormalMeta, Nothing}}, data::Tuple{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, Tuple{SingleObservable{Marginal{PointMass{Float64}, Nothing}, AsapScheduler}}})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\operators\map.jl:62 [inlined]
# --- the last 2 lines are repeated 1 more time ---
#  [22] next!(actor::Actor{T}, data::T) where T
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:206 [inlined]
#  [23] next_received!(wrapper::Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}}, Rocket.MapActor{Tuple{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}}, Rocket.MapActor{AbstractMessage, Rocket.ScheduledActor{AbstractMessage, RxInfer.LimitStackScheduler, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}}, var"#21#23"{Channel{Any}}}, ReactiveMP.var"#217#218"{ReactiveMP.MessageMapping{NormalMeanPrecision, Val{:μ}, Marginalisation, Nothing, Val{(:out, :τ)}, GammaMeta, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus}, data::Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}, index::Int64)
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\combined.jl:101
#  [24] on_next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\combined.jl:68 [inlined]
#  [25] next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:206 [inlined]
#  [26] next_received!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\combined_updates.jl:65 [inlined]
#  [27] on_next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\combined_updates.jl:34 [inlined]
#  [28] next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:206 [inlined]
#  [29] on_next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\operators\map.jl:62 [inlined]
#  [30] scheduled_next!(actor::Rocket.MapActor{Message{PointMass{Float64}}, Rocket.CombineLatestUpdatesInnerActor{Marginal, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}, Rocket.CombineLatestInnerActor{Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}}, Rocket.MapActor{Tuple{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}}, Rocket.MapActor{AbstractMessage, Rocket.ScheduledActor{AbstractMessage, RxInfer.LimitStackScheduler, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}}, var"#21#23"{Channel{Any}}}, ReactiveMP.var"#217#218"{ReactiveMP.MessageMapping{NormalMeanPrecision, Val{:μ}, Marginalisation, Nothing, Val{(:out, :τ)}, GammaMeta, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus}}, typeof(as_marginal)}, value::Message{PointMass{Float64}, Nothing}, ::AsapScheduler)
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\schedulers\asap.jl:23
#  [31] on_next!(subject::Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}, data::Message{PointMass{Float64}, Nothing})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\subjects\subject.jl:62
#  [32] actor_on_next!(::BaseActorTrait{Message{PointMass{Float64}}}, actor::Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}, data::Message{PointMass{Float64}, Nothing})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:250
#  [33] next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:202 [inlined]
#  [34] on_next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\subjects\recent.jl:62 [inlined]
#  [35] actor_on_next!(::BaseActorTrait{Message{PointMass{Float64}}}, actor::Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}, data::Message{PointMass{Float64}, Nothing})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:250 [inlined]
#  [36] next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:202 [inlined]
#  [37] update!
#     @ C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\variables\data.jl:156 [inlined]
#  [38] update!
#     @ C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\variables\data.jl:132 [inlined]
#  [39] #143
#     @ C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\variables\data.jl:165 [inlined]
#  [40] foreach(f::ReactiveMP.var"#143#144", itr::Base.Iterators.Zip{Tuple{Vector{DataVariable{PointMass{Float64}, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}}}, Vector{Float64}}})
#     @ Base .\abstractarray.jl:3094
#  [41] update!(datavars::Vector{DataVariable{PointMass{Float64}, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}}}, data::Vector{Float64})
#     @ ReactiveMP C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\variables\data.jl:164
#  [42] __inference(; model::RxInfer.ModelGenerator{var"###state_space_model#344", Tuple{Int64, Int64, Nothing, ThreadsReusingPipelineStage{NormalMeanVariance{Float64}}, ThreadsReusingPipelineStage{Gamma{Float64}}}, @NamedTuple{}}, data::@NamedTuple{y::Vector{Float64}}, initmarginals::@NamedTuple{τ_y::Gamma{Float64}}, initmessages::Nothing, constraints::ConstraintsSpecification{Tuple{ReactiveMP.FactorisationConstraintsSpecification{(:x0, :τ_y, :x), (q(x0, x), q(τ_y))}}, @NamedTuple{}, @NamedTuple{}}, meta::Nothing, options::@NamedTuple{limit_stack_depth::Int64}, returnvars::Nothing, predictvars::Nothing, iterations::Int64, free_energy::Bool, free_energy_diagnostics::Tuple{BetheFreeEnergyCheckNaNs, BetheFreeEnergyCheckInfs}, showprogress::Bool, callbacks::@NamedTuple{before_iteration::var"#171#174"{Base.RefValue{Float64}}, after_iteration::var"#172#175"{Base.RefValue{Float64}, Base.RefValue{Float64}}}, addons::Nothing, postprocess::DefaultPostprocess, warn::Bool, catch_exception::Bool)
#     @ RxInfer C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\inference.jl:496
#  [43] __inference
#     @ RxInfer C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\inference.jl:282 [inlined]
#  [44] #infer#251
#     @ RxInfer C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\inference.jl:1805 [inlined]
#  [45] (::var"#170#173"{Nothing, ThreadsReusingPipelineStage{NormalMeanVariance{Float64}}, ThreadsReusingPipelineStage{Gamma{Float64}}, Int64, Int64, Int64, Nothing})()
#     @ Main .\In[34]:9
#  [46] execute_benchmark(f::var"#170#173"{Nothing, ThreadsReusingPipelineStage{NormalMeanVariance{Float64}}, ThreadsReusingPipelineStage{Gamma{Float64}}, Int64, Int64, Int64, Nothing}, n::Int64)
#     @ Main .\In[32]:4
#  [47] (::var"#177#178"{Int64, Int64, Nothing, Vector{Pair{Symbol, Tuple{Any, Any, Any}}}, Int64})(order::Int64)
#     @ Main .\In[35]:9
#  [48] (::ProgressMeter.var"#45#48"{Distributed.RemoteChannel{Channel{Bool}}, var"#177#178"{Int64, Int64, Nothing, Vector{Pair{Symbol, Tuple{Any, Any, Any}}}, Int64}})(x::Int64)
#     @ ProgressMeter C:\Users\matti\.julia\packages\ProgressMeter\vnCY0\src\ProgressMeter.jl:1036
#  [49] iterate(g::Base.Generator, s::Vararg{Any})
#     @ Base .\generator.jl:47 [inlined]
#  [50] _collect(c::StepRange{Int64, Int64}, itr::Base.Generator{StepRange{Int64, Int64}, ProgressMeter.var"#45#48"{Distributed.RemoteChannel{Channel{Bool}}, var"#177#178"{Int64, Int64, Nothing, Vector{Pair{Symbol, Tuple{Any, Any, Any}}}, Int64}}}, ::Base.EltypeUnknown, isz::Base.HasShape{1})
#     @ Base .\array.jl:854
#  [51] collect_similar(cont::StepRange{Int64, Int64}, itr::Base.Generator{StepRange{Int64, Int64}, ProgressMeter.var"#45#48"{Distributed.RemoteChannel{Channel{Bool}}, var"#177#178"{Int64, Int64, Nothing, Vector{Pair{Symbol, Tuple{Any, Any, Any}}}, Int64}}})
#     @ Base .\array.jl:763
#  [52] map(f::Function, A::StepRange{Int64, Int64})
#     @ Base .\abstractarray.jl:3282
#  [53] macro expansion
#     @ C:\Users\matti\.julia\packages\ProgressMeter\vnCY0\src\ProgressMeter.jl:1035 [inlined]
#  [54] macro expansion
#     @ .\task.jl:479 [inlined]
#  [55] macro expansion
#     @ C:\Users\matti\.julia\packages\ProgressMeter\vnCY0\src\ProgressMeter.jl:1034 [inlined]
#  [56] macro expansion
#     @ .\task.jl:479 [inlined]
#  [57] progress_map(::Function, ::Vararg{Any}; mapfun::typeof(map), progress::Progress, channel_bufflen::Int64, kwargs::@Kwargs{})
#     @ ProgressMeter C:\Users\matti\.julia\packages\ProgressMeter\vnCY0\src\ProgressMeter.jl:1027
#  [58] progress_map
#     @ C:\Users\matti\.julia\packages\ProgressMeter\vnCY0\src\ProgressMeter.jl:1018 [inlined]
#  [59] #run_big_benchmark#176
#     @ .\In[35]:2 [inlined]
#  [60] run_big_benchmark
#     @ .\In[35]:1 [inlined]
#  [61] plot_benchmark(combinations::Vector{Pair{Symbol, Tuple{Any, Any, Any}}}, sizes::StepRange{Int64, Int64}, n::Int64, niterations::Int64, stop_tol::Nothing)
#     @ Main .\In[37]:2

# %%
leg = plot(
    framestyle = :none,
    legend = :top,
    legend_column = 2
)

for (key, values) in pairs(ordered_combinations)
    plot!(leg, [0, 0], [0, 0], label = string(key))
end
l = @layout [a{0.2h}; b; c]

plot(
    leg, p1, p2,
    layout = l,
    size = (300, 500),
)

# %%
savefig("plots/state_space_2.tikz")
# Out:
# "c:\\Users\\matti\\Documents\\TUe\\Thesis\\ThesisParallelMP\\benchmarks\\plots\\state_space_2.tikz"

# %%
sizes = 10:2:22
niterations = 100

p1 = plot_benchmark(combinations, sizes, 100, niterations, 1e-2)
p2 = plot_benchmark(combinations, sizes, 100, niterations, 1e-10);
# Out:
# `ProductOf` object cannot be used as a functional form in inference backend. Use form constraints to restrict the functional form of marginal posteriors.
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] constrain_form(::UnspecifiedFormConstraint, something::ProductOf{GammaShapeRate{Float64}, NormalWeightedMeanPrecision{Float64}})
#     @ ReactiveMP C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\constraints\form.jl:140
#   [3] constrain_form_as_message(message::Message{ProductOf{GammaShapeRate{Float64}, NormalWeightedMeanPrecision{Float64}}, Nothing}, form_constraint::UnspecifiedFormConstraint)
#     @ ReactiveMP C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\message.jl:140
#   [4] (::ReactiveMP.var"#15#17"{GenericProd, UnspecifiedFormConstraint})(messages::Vector{AbstractMessage})
#     @ ReactiveMP C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\message.jl:150
#   [5] (::ReactiveMP.var"#117#118"{ReactiveMP.var"#15#17"{GenericProd, UnspecifiedFormConstraint}})(messages::Vector{AbstractMessage})
#     @ ReactiveMP C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\variables\variable.jl:70
#   [6] next_received!(wrapper::Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#117#118"{ReactiveMP.var"#15#17"{GenericProd, UnspecifiedFormConstraint}}}, data::ChanneledMessage{Channel{Any}}, index::CartesianIndex{1})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\collected.jl:97
#   [7] on_next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\collected.jl:87 [inlined]
#   [8] scheduled_next!(actor::Rocket.CollectLatestObservableInnerActor{AbstractMessage, CartesianIndex{1}, Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#117#118"{ReactiveMP.var"#15#17"{GenericProd, UnspecifiedFormConstraint}}}}, value::ChanneledMessage{Channel{Any}}, ::AsapScheduler)
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\schedulers\asap.jl:23
#   [9] on_next!(subject::Subject{AbstractMessage, AsapScheduler, AsapScheduler}, data::ChanneledMessage{Channel{Any}})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\subjects\subject.jl:62
#  [10] actor_on_next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:250 [inlined]
#  [11] next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:202 [inlined]
#  [12] on_next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\subjects\recent.jl:62 [inlined]
#  [13] #7
#     @ C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\rocket.jl:86 [inlined]
#  [14] limitstack(callback::RxInfer.var"#7#8"{Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ChanneledMessage{Channel{Any}}}, instance::RxInfer.LimitStackScheduler)
#     @ RxInfer C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\rocket.jl:52
#  [15] scheduled_next!
#     @ C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\rocket.jl:86 [inlined]
#  [16] actor_on_next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:255 [inlined]
#  [17] next!(actor::Actor{T}, data::T) where T
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:203 [inlined]
#  [18] on_next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\scheduled.jl:12 [inlined]
#  [19] next!(actor::Actor{T}, data::T) where T
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:206 [inlined]
#  [20] on_next!(actor::Rocket.MapActor{Tuple{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, Tuple{SingleObservable{Marginal{PointMass{Float64}, Nothing}, AsapScheduler}}}, Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}}, ReactiveMP.MarginalMapping{NormalMeanVariance, Val{:out_μ}, Val{(:out, :μ)}, Val{(:v,)}, NormalMeta, Nothing}}, data::Tuple{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, Tuple{SingleObservable{Marginal{PointMass{Float64}, Nothing}, AsapScheduler}}})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\operators\map.jl:62 [inlined]
# --- the last 2 lines are repeated 1 more time ---
#  [23] next!(actor::Actor{T}, data::T) where T
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:206 [inlined]
#  [24] next_received!(wrapper::Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}}, Rocket.MapActor{Tuple{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}}, Rocket.MapActor{AbstractMessage, Rocket.ScheduledActor{AbstractMessage, RxInfer.LimitStackScheduler, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}}, var"#21#23"{Channel{Any}}}, ReactiveMP.var"#217#218"{ReactiveMP.MessageMapping{NormalMeanPrecision, Val{:τ}, Marginalisation, Nothing, Val{(:out, :μ)}, GammaMeta, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus}, data::Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}, index::Int64)
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\combined.jl:101
#  [25] on_next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\combined.jl:68 [inlined]
#  [26] next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:206 [inlined]
#  [27] next_received!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\combined_updates.jl:65 [inlined]
#  [28] on_next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\observable\combined_updates.jl:34 [inlined]
#  [29] next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:206 [inlined]
#  [30] on_next!
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\operators\map.jl:62 [inlined]
#  [31] scheduled_next!(actor::Rocket.MapActor{Message{PointMass{Float64}}, Rocket.CombineLatestUpdatesInnerActor{Marginal, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}, Rocket.CombineLatestInnerActor{Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}}, Rocket.MapActor{Tuple{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Float64}}, typeof(as_marginal)}}, ReactiveMP.MarginalObservable}}, Rocket.MapActor{AbstractMessage, Rocket.ScheduledActor{AbstractMessage, RxInfer.LimitStackScheduler, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}}, var"#21#23"{Channel{Any}}}, ReactiveMP.var"#217#218"{ReactiveMP.MessageMapping{NormalMeanPrecision, Val{:τ}, Marginalisation, Nothing, Val{(:out, :μ)}, GammaMeta, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus}}, typeof(as_marginal)}, value::Message{PointMass{Float64}, Nothing}, ::AsapScheduler)
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\schedulers\asap.jl:23
#  [32] on_next!(subject::Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}, data::Message{PointMass{Float64}, Nothing})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\subjects\subject.jl:62
#  [33] actor_on_next!(::BaseActorTrait{Message{PointMass{Float64}}}, actor::Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}, data::Message{PointMass{Float64}, Nothing})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:250
#  [34] next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:202 [inlined]
#  [35] on_next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\subjects\recent.jl:62 [inlined]
#  [36] actor_on_next!(::BaseActorTrait{Message{PointMass{Float64}}}, actor::Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}, data::Message{PointMass{Float64}, Nothing})
#     @ Rocket C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:250 [inlined]
#  [37] next!
#     @ C:\Users\matti\.julia\packages\Rocket\izwZh\src\actor.jl:202 [inlined]
#  [38] update!
#     @ C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\variables\data.jl:156 [inlined]
#  [39] update!
#     @ C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\variables\data.jl:132 [inlined]
#  [40] #143
#     @ C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\variables\data.jl:165 [inlined]
#  [41] foreach(f::ReactiveMP.var"#143#144", itr::Base.Iterators.Zip{Tuple{Vector{DataVariable{PointMass{Float64}, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}}}, Vector{Float64}}})
#     @ Base .\abstractarray.jl:3094
#  [42] update!(datavars::Vector{DataVariable{PointMass{Float64}, Rocket.RecentSubjectInstance{Message{PointMass{Float64}}, Subject{Message{PointMass{Float64}}, AsapScheduler, AsapScheduler}}}}, data::Vector{Float64})
#     @ ReactiveMP C:\Users\matti\.julia\packages\ReactiveMP\AjKNY\src\variables\data.jl:164
#  [43] __inference(; model::RxInfer.ModelGenerator{var"###state_space_model#344", Tuple{Int64, Int64, Nothing, ThreadsReusingPipelineStage{NormalMeanVariance{Float64}}, ThreadsReusingPipelineStage{NormalMeanVariance{Float64}}}, @NamedTuple{}}, data::@NamedTuple{y::Vector{Float64}}, initmarginals::@NamedTuple{τ_y::Gamma{Float64}}, initmessages::Nothing, constraints::ConstraintsSpecification{Tuple{ReactiveMP.FactorisationConstraintsSpecification{(:x0, :τ_y, :x), (q(x0, x), q(τ_y))}}, @NamedTuple{}, @NamedTuple{}}, meta::Nothing, options::@NamedTuple{limit_stack_depth::Int64}, returnvars::Nothing, predictvars::Nothing, iterations::Int64, free_energy::Bool, free_energy_diagnostics::Tuple{BetheFreeEnergyCheckNaNs, BetheFreeEnergyCheckInfs}, showprogress::Bool, callbacks::@NamedTuple{before_iteration::var"#171#174"{Base.RefValue{Float64}}, after_iteration::var"#172#175"{Base.RefValue{Float64}, Base.RefValue{Float64}}}, addons::Nothing, postprocess::DefaultPostprocess, warn::Bool, catch_exception::Bool)
#     @ RxInfer C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\inference.jl:496
#  [44] __inference
#     @ RxInfer C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\inference.jl:282 [inlined]
#  [45] #infer#251
#     @ RxInfer C:\Users\matti\.julia\packages\RxInfer\gw5B4\src\inference.jl:1805 [inlined]
#  [46] (::var"#170#173"{Nothing, ThreadsReusingPipelineStage{NormalMeanVariance{Float64}}, ThreadsReusingPipelineStage{NormalMeanVariance{Float64}}, Int64, Int64, Int64, Float64})()
#     @ Main .\In[34]:9
#  [47] execute_benchmark(f::var"#170#173"{Nothing, ThreadsReusingPipelineStage{NormalMeanVariance{Float64}}, ThreadsReusingPipelineStage{NormalMeanVariance{Float64}}, Int64, Int64, Int64, Float64}, n::Int64)
#     @ Main .\In[32]:4
#  [48] (::var"#177#178"{Int64, Int64, Float64, Vector{Pair{Symbol, Tuple{Any, Any, Any}}}, Int64})(order::Int64)
#     @ Main .\In[35]:9
#  [49] (::ProgressMeter.var"#45#48"{Distributed.RemoteChannel{Channel{Bool}}, var"#177#178"{Int64, Int64, Float64, Vector{Pair{Symbol, Tuple{Any, Any, Any}}}, Int64}})(x::Int64)
#     @ ProgressMeter C:\Users\matti\.julia\packages\ProgressMeter\vnCY0\src\ProgressMeter.jl:1036
#  [50] iterate(g::Base.Generator, s::Vararg{Any})
#     @ Base .\generator.jl:47 [inlined]
#  [51] _collect(c::StepRange{Int64, Int64}, itr::Base.Generator{StepRange{Int64, Int64}, ProgressMeter.var"#45#48"{Distributed.RemoteChannel{Channel{Bool}}, var"#177#178"{Int64, Int64, Float64, Vector{Pair{Symbol, Tuple{Any, Any, Any}}}, Int64}}}, ::Base.EltypeUnknown, isz::Base.HasShape{1})
#     @ Base .\array.jl:854
#  [52] collect_similar(cont::StepRange{Int64, Int64}, itr::Base.Generator{StepRange{Int64, Int64}, ProgressMeter.var"#45#48"{Distributed.RemoteChannel{Channel{Bool}}, var"#177#178"{Int64, Int64, Float64, Vector{Pair{Symbol, Tuple{Any, Any, Any}}}, Int64}}})
#     @ Base .\array.jl:763
#  [53] map(f::Function, A::StepRange{Int64, Int64})
#     @ Base .\abstractarray.jl:3282
#  [54] macro expansion
#     @ C:\Users\matti\.julia\packages\ProgressMeter\vnCY0\src\ProgressMeter.jl:1035 [inlined]
#  [55] macro expansion
#     @ .\task.jl:479 [inlined]
#  [56] macro expansion
#     @ C:\Users\matti\.julia\packages\ProgressMeter\vnCY0\src\ProgressMeter.jl:1034 [inlined]
#  [57] macro expansion
#     @ .\task.jl:479 [inlined]
#  [58] progress_map(::Function, ::Vararg{Any}; mapfun::typeof(map), progress::Progress, channel_bufflen::Int64, kwargs::@Kwargs{})
#     @ ProgressMeter C:\Users\matti\.julia\packages\ProgressMeter\vnCY0\src\ProgressMeter.jl:1027
#  [59] progress_map
#     @ C:\Users\matti\.julia\packages\ProgressMeter\vnCY0\src\ProgressMeter.jl:1018 [inlined]
#  [60] #run_big_benchmark#176
#     @ .\In[35]:2 [inlined]
#  [61] run_big_benchmark
#     @ .\In[35]:1 [inlined]
#  [62] plot_benchmark(combinations::Vector{Pair{Symbol, Tuple{Any, Any, Any}}}, sizes::StepRange{Int64, Int64}, n::Int64, niterations::Int64, stop_tol::Float64)
#     @ Main .\In[37]:2

# %%
leg = plot(
    framestyle = :none,
    legend = :top,
    legend_column = 2
)

for (key, values) in pairs(ordered_combinations)
    plot!(leg, [0, 0], [0, 0], label = string(key))
end
l = @layout [a{0.2h}; b; c]

plot(
    leg, p1, p2,
    layout = l,
    size = (300, 500),
)

# %%
savefig("plots/state_space_2_convergence.tikz")
# Out:
# "c:\\Users\\matti\\Documents\\TUe\\Thesis\\ThesisParallelMP\\benchmarks\\plots\\state_space_2_convergence.tikz"
